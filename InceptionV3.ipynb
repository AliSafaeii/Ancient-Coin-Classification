# %%
# !pip install keras-nightly

# %%
import pandas as pd
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D, Reshape, Multiply, Add, ReLU, GlobalMaxPooling2D, Lambda, Concatenate
from keras.optimizers import Adam
from keras.applications import VGG16, InceptionV3
from tensorflow.keras import backend as K
import numpy as np
import time
import matplotlib.image as mpimg
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Train_dataset_path = '/content/drive/MyDrive/Reverse/Train'
Validation_dataset_path = '/content/drive/MyDrive/Reverse/Validation'
Test_dataset_path = '/content/drive/MyDrive/Reverse/Test'

# %%
image_size = (299, 299)

# Create a data generator
datagen = ImageDataGenerator(rescale=1./255)

# Load training data
train_data = datagen.flow_from_directory(
    Train_dataset_path,
    target_size=image_size,
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)

# Load validation data
val_data = datagen.flow_from_directory(
    Validation_dataset_path,
    target_size=image_size,
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Load test data
test_data = datagen.flow_from_directory(
    Test_dataset_path,
    target_size=image_size,
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# %%
class_name = '60'

# Path to the specific class folder
class_folder = os.path.join(Train_dataset_path, class_name)

# Check the contents of the folder
images = os.listdir(class_folder)
print(f"Number of images in class {class_name}: {len(images)}")
# Randomly sample an image
random_image = random.choice(images)
random_image_path = os.path.join(class_folder, random_image)

print(f"Randomly selected image: {random_image}")
# Read and plot the image
img = mpimg.imread(random_image_path)
plt.imshow(img)
plt.axis('off')
plt.title(f"Class: {class_name}")
plt.show()
# Out:
# Number of images in class 60: 100
# Randomly selected image: 58.png

# %%
# Get all class folders
class_folders = sorted(os.listdir(Train_dataset_path))

# Randomly sample 12 different classes
selected_classes = random.sample(class_folders, 12)

# Create a figure for plotting
fig, axes = plt.subplots(3, 4, figsize=(12, 9))

for ax, class_name in zip(axes.flatten(), selected_classes):
    class_folder = os.path.join(Train_dataset_path, class_name)
    images = os.listdir(class_folder)
    if images:  # Ensure there are images in the class folder
        random_image = random.choice(images)
        random_image_path = os.path.join(class_folder, random_image)
        img = mpimg.imread(random_image_path)

        ax.imshow(img)
        ax.axis('off')
        ax.set_title(f"Class: {class_name}")

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.savefig("images_plot.png")  # Save the plot as an image file
plt.show()

# %% [markdown]
# #Frozen Base Model

# %%
# Define the base model
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

for layer in base_model.layers:
    layer.trainable = False

base_model.summary()

# %% [markdown]
# ##Model1

# %%
#Define the model

model1 = Sequential([
   # keras.Input(shape=(299, 299, 3)),
   # data_augmentation,
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    #Dropout(0.30),
    Dense(128, activation='relu'),
    #Dropout(0.30),
    Dense(60, activation='softmax')
])

# %%
model1.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
early_stop = [keras.callbacks.EarlyStopping(monitor="val_loss", patience=3)]

# %%
history = model1.fit(
    x = train_data,
    epochs=40,
    validation_data=val_data,
    callbacks=early_stop
)

test_loss, test_accuracy = model1.evaluate(val_data)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
models_path='/content/drive/My Drive/CNN_Models/InceptionV3BasedModel.h5'
model1.save(models_path)


# Plot training and test accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training and test loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/40
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 136s 731ms/step - accuracy: 0.1055 - loss: 3.7856 - val_accuracy: 0.4292 - val_loss: 2.2582
# Epoch 2/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 89s 569ms/step - accuracy: 0.5285 - loss: 1.8413 - val_accuracy: 0.6708 - val_loss: 1.2781
# Epoch 3/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 89s 567ms/step - accuracy: 0.7218 - loss: 1.0554 - val_accuracy: 0.7250 - val_loss: 0.9823
# Epoch 4/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 89s 565ms/step - accuracy: 0.7928 - loss: 0.7707 - val_accuracy: 0.7708 - val_loss: 0.8477
# Epoch 5/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 140s 560ms/step - accuracy: 0.8526 - loss: 0.5557 - val_accuracy: 0.8008 - val_loss: 0.7204
# Epoch 6/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 88s 564ms/step - accuracy: 0.8885 - loss: 0.4262 - val_accuracy: 0.8292 - val_loss: 0.6225
# Epoch 7/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 142s 568ms/step - accuracy: 0.9015 - loss: 0.3779 - val_accuracy: 0.8200 - val_loss: 0.6283
# Epoch 8/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 88s 564ms/step - accuracy: 0.9210 - loss: 0.3101 - val_accuracy: 0.8233 - val_loss: 0.6209
# Epoch 9/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 95s 611ms/step - accuracy: 0.9279 - loss: 0.2493 - val_accuracy: 0.8192 - val_loss: 0.5916
# Epoch 10/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 134s 561ms/step - accuracy: 0.9564 - loss: 0.1878 - val_accuracy: 0.8483 - val_loss: 0.5082
# Epoch 11/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 87s 557ms/step - accuracy: 0.9673 - loss: 0.1567 - val_accuracy: 0.8583 - val_loss: 0.5246
# Epoch 12/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 88s 560ms/step - accuracy: 0.9669 - loss: 0.1509 - val_accuracy: 0.8625 - val_loss: 0.4996
# Epoch 13/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 144s 574ms/step - accuracy: 0.9803 - loss: 0.1042 - val_accuracy: 0.8533 - val_loss: 0.5004
# Epoch 14/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 143s 574ms/step - accuracy: 0.9695 - loss: 0.1243 - val_accuracy: 0.8167 - val_loss: 0.6995
# Epoch 15/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 90s 576ms/step - accuracy: 0.9493 - loss: 0.1805 - val_accuracy: 0.8583 - val_loss: 0.4893
# Epoch 16/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 89s 571ms/step - accuracy: 0.9874 - loss: 0.0659 - val_accuracy: 0.8658 - val_loss: 0.4998
# Epoch 17/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 96s 613ms/step - accuracy: 0.9898 - loss: 0.0592 - val_accuracy: 0.8692 - val_loss: 0.4703
# Epoch 18/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 135s 575ms/step - accuracy: 0.9942 - loss: 0.0456 - val_accuracy: 0.8742 - val_loss: 0.4816
# Epoch 19/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 89s 569ms/step - accuracy: 0.9953 - loss: 0.0355 - val_accuracy: 0.8717 - val_loss: 0.4899
# Epoch 20/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 91s 574ms/step - accuracy: 0.9869 - loss: 0.0586 - val_accuracy: 0.8750 - val_loss: 0.4622
# Epoch 21/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 141s 577ms/step - accuracy: 0.9956 - loss: 0.0281 - val_accuracy: 0.8608 - val_loss: 0.5099
# Epoch 22/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 91s 581ms/step - accuracy: 0.9955 - loss: 0.0286 - val_accuracy: 0.8700 - val_loss: 0.5025
# Epoch 23/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 92s 586ms/step - accuracy: 0.9932 - loss: 0.0354 - val_accuracy: 0.8700 - val_loss: 0.5252
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 15s 399ms/step - accuracy: 0.8567 - loss: 0.5785
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test Loss: 0.5251907110214233
# Test Accuracy: 0.8700000047683716

# %%
# Load the saved model
models_path='/content/drive/My Drive/CNN_Models/InceptionV3BasedModel.h5'
loaded_model = keras.models.load_model(models_path)

# Evaluate the model on the test dataset
test_loss, test_accuracy = loaded_model.evaluate(test_data)
print('Loaded Model Test Loss:', test_loss)
print('Loaded Model Test Accuracy:', test_accuracy)

# %% [markdown]
# #Model2

# %%
#Define the model2

model2 = Sequential([
    #keras.Input(shape=(299, 299, 3)),
    #data_augmentation,
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.10),
    Dense(128, activation='relu'),
    Dropout(0.10),
    Dense(60, activation='softmax')
])

# %%
model2.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
early_stop = [keras.callbacks.EarlyStopping(monitor="val_loss", patience=3)]

# %%
history = model2.fit(
    x = train_data,
    epochs=40,
    validation_data=val_data,
    callbacks=early_stop
)

test_loss, test_accuracy = model2.evaluate(val_data)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
models_path='/content/drive/My Drive/CNN_Models/InceptionV3BasedModel2.keras'
model2.save(models_path)


# Plot training and test accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training and test loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/40
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 2532s 16s/step - accuracy: 0.0667 - loss: 3.9283 - val_accuracy: 0.3675 - val_loss: 2.7302
# Epoch 2/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 75s 478ms/step - accuracy: 0.3290 - loss: 2.5351 - val_accuracy: 0.5875 - val_loss: 1.6113
# Epoch 3/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 75s 474ms/step - accuracy: 0.5547 - loss: 1.5946 - val_accuracy: 0.7050 - val_loss: 1.1053
# Epoch 4/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 75s 477ms/step - accuracy: 0.6565 - loss: 1.1508 - val_accuracy: 0.7567 - val_loss: 0.9171
# Epoch 5/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 75s 476ms/step - accuracy: 0.7313 - loss: 0.9314 - val_accuracy: 0.8008 - val_loss: 0.7593
# Epoch 6/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 74s 473ms/step - accuracy: 0.7811 - loss: 0.7437 - val_accuracy: 0.8108 - val_loss: 0.7002
# Epoch 7/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 75s 479ms/step - accuracy: 0.8037 - loss: 0.6740 - val_accuracy: 0.8175 - val_loss: 0.6560
# Epoch 8/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 75s 480ms/step - accuracy: 0.8329 - loss: 0.5426 - val_accuracy: 0.8117 - val_loss: 0.6614
# Epoch 9/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 76s 485ms/step - accuracy: 0.8570 - loss: 0.4767 - val_accuracy: 0.8225 - val_loss: 0.6274
# Epoch 10/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 76s 483ms/step - accuracy: 0.8494 - loss: 0.5189 - val_accuracy: 0.8283 - val_loss: 0.6230
# Epoch 11/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 77s 488ms/step - accuracy: 0.8920 - loss: 0.3543 - val_accuracy: 0.8600 - val_loss: 0.5127
# Epoch 12/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 77s 490ms/step - accuracy: 0.8941 - loss: 0.3247 - val_accuracy: 0.8550 - val_loss: 0.5123
# Epoch 13/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 77s 490ms/step - accuracy: 0.9101 - loss: 0.2969 - val_accuracy: 0.8367 - val_loss: 0.5604
# Epoch 14/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 77s 489ms/step - accuracy: 0.9077 - loss: 0.2901 - val_accuracy: 0.8467 - val_loss: 0.5255
# Epoch 15/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 77s 487ms/step - accuracy: 0.9129 - loss: 0.2839 - val_accuracy: 0.8533 - val_loss: 0.5122
# Epoch 16/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 77s 489ms/step - accuracy: 0.9254 - loss: 0.2471 - val_accuracy: 0.8792 - val_loss: 0.4587
# Epoch 17/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 77s 491ms/step - accuracy: 0.9150 - loss: 0.2597 - val_accuracy: 0.8717 - val_loss: 0.4820
# Epoch 18/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 77s 489ms/step - accuracy: 0.9354 - loss: 0.2150 - val_accuracy: 0.8467 - val_loss: 0.5269
# Epoch 19/40
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 77s 490ms/step - accuracy: 0.9354 - loss: 0.2020 - val_accuracy: 0.8558 - val_loss: 0.5016
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 12s 312ms/step - accuracy: 0.8724 - loss: 0.4775
# Test Loss: 0.5016115307807922
# Test Accuracy: 0.8558333516120911

# %%
# Load the saved model
models_path='/content/drive/My Drive/CNN_Models/InceptionV3BasedModel2.keras'
loaded_model = keras.models.load_model(models_path)

# Evaluate the model on the test dataset
test_loss, test_accuracy = loaded_model.evaluate(test_data)
print('Loaded Model Test Loss:', test_loss)
print('Loaded Model Test Accuracy:', test_accuracy)

# %% [markdown]
# #Model3

# %%
# Define the base model
trainable_base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

for layer in trainable_base_model.layers[-31:]:
  layer.trainable = True

for layer in trainable_base_model.layers[:-31]:
  layer.trainable = False

trainable_base_model.summary()

# %%
#Define the model3

model3 = Sequential([
    trainable_base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.10),
    Dense(128, activation='relu'),
    Dropout(0.10),
    Dense(60, activation='softmax')
])

# %%
checkpoint_filepath1 = '/content/drive/My Drive/CNN_Models/InceptionV3BasedModel3.keras'

# %%
# Define callbacks
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

model_checkpoint = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath1,
    monitor='val_loss',
    save_best_only=True
)

# %%
model3.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model3.fit(
    x = train_data,
    epochs=50,
    validation_data=val_data,
    callbacks=[early_stopping, model_checkpoint]
)

test_loss, test_accuracy = model3.evaluate(val_data)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)


# Plot training and test accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training and test loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 5051s 32s/step - accuracy: 0.1913 - loss: 3.4995 - val_accuracy: 0.7500 - val_loss: 1.4398
# Epoch 2/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 74s 474ms/step - accuracy: 0.7850 - loss: 1.0953 - val_accuracy: 0.9200 - val_loss: 0.4659
# Epoch 3/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 74s 466ms/step - accuracy: 0.9265 - loss: 0.3900 - val_accuracy: 0.9342 - val_loss: 0.2970
# Epoch 4/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 74s 468ms/step - accuracy: 0.9687 - loss: 0.1944 - val_accuracy: 0.9458 - val_loss: 0.2373
# Epoch 5/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 74s 468ms/step - accuracy: 0.9814 - loss: 0.1148 - val_accuracy: 0.9508 - val_loss: 0.2150
# Epoch 6/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 73s 461ms/step - accuracy: 0.9926 - loss: 0.0626 - val_accuracy: 0.9183 - val_loss: 0.3110
# Epoch 7/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 73s 467ms/step - accuracy: 0.9909 - loss: 0.0779 - val_accuracy: 0.9492 - val_loss: 0.2019
# Epoch 8/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 74s 469ms/step - accuracy: 0.9947 - loss: 0.0360 - val_accuracy: 0.9475 - val_loss: 0.1962
# Epoch 9/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 72s 458ms/step - accuracy: 0.9970 - loss: 0.0287 - val_accuracy: 0.9475 - val_loss: 0.2024
# Epoch 10/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 74s 473ms/step - accuracy: 0.9926 - loss: 0.0515 - val_accuracy: 0.9550 - val_loss: 0.1862
# Epoch 11/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 74s 470ms/step - accuracy: 0.9936 - loss: 0.0350 - val_accuracy: 0.9583 - val_loss: 0.1787
# Epoch 12/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 73s 460ms/step - accuracy: 0.9958 - loss: 0.0311 - val_accuracy: 0.9517 - val_loss: 0.1919
# Epoch 13/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 73s 463ms/step - accuracy: 0.9917 - loss: 0.0417 - val_accuracy: 0.9475 - val_loss: 0.1897
# Epoch 14/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 72s 462ms/step - accuracy: 0.9983 - loss: 0.0156 - val_accuracy: 0.9500 - val_loss: 0.1922
# Epoch 15/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 73s 460ms/step - accuracy: 0.9951 - loss: 0.0266 - val_accuracy: 0.9517 - val_loss: 0.1879
# Epoch 16/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 72s 463ms/step - accuracy: 0.9987 - loss: 0.0111 - val_accuracy: 0.9533 - val_loss: 0.1952
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 291ms/step - accuracy: 0.9588 - loss: 0.1761
# Test Loss: 0.17872363328933716
# Test Accuracy: 0.9583333134651184

# %%
models_path = '/content/drive/My Drive/CNN_Models/InceptionV3BasedModel3.keras'
# Load the saved model
loaded_model = keras.models.load_model(models_path)

# Evaluate the model on the test dataset
test_loss, test_accuracy = loaded_model.evaluate(test_data)
print('Loaded Model Test Loss:', test_loss)
print('Loaded Model Test Accuracy:', test_accuracy)

# %% [markdown]
# #Model4 (1 SE Block)

# %%
# Define the base model
trainable_base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

for layer in trainable_base_model.layers[-31:]:
  layer.trainable = True

for layer in trainable_base_model.layers[:-31]:
  layer.trainable = False

trainable_base_model.summary()

# %%
def squeeze_excite_block(input_tensor, ratio):
    """
    Create a Squeeze-and-Excitation block.

    Args:
        input_tensor: Input Keras tensor (e.g., output of a convolutional layer).
        ratio: Reduction ratio for the bottleneck (usually 16).

    Returns:
        Keras tensor after applying the SE block.
    """
    # Get the number of channels in the input tensor
    channel_axis = -1
    channels = input_tensor.shape[channel_axis]

    # Squeeze: Global Average Pooling
    se = GlobalAveragePooling2D()(input_tensor)

    # Excitation: Bottleneck structure
    se = Dense(channels // ratio, activation='relu')(se)  # Bottleneck (reduce channels)
    se = Dense(channels, activation='sigmoid')(se)       # Restore channels

    # Reshape to match the input tensor dimensions
    se = Reshape((1, 1, channels))(se)

    # Recalibrate: Scale the input tensor with the channel-wise weights
    x = Multiply()([input_tensor, se])

    return x

# %%
#Code for the whole process
x = trainable_base_model.output
x = squeeze_excite_block(x, 16)
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.10)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.10)(x)
output_tensor = Dense(60, activation='softmax')(x)

# %%
#Final Model
model4 = Model(inputs=trainable_base_model.input, outputs=output_tensor)
model4.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
model4.summary()

# %%
checkpoint_filepath2 = '/content/drive/My Drive/CNN_Models/InceptionV3BasedModel4.keras'

# %%
# Define callbacks
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

model_checkpoint = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath2,
    monitor='val_loss',
    save_best_only=True
)

# %%
history = model4.fit(
    x = train_data,
    epochs=50,
    validation_data=val_data,
    callbacks=[early_stopping, model_checkpoint]
)

test_loss, test_accuracy = model4.evaluate(val_data)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)


# Plot training and test accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training and test loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 2737s 17s/step - accuracy: 0.1583 - loss: 3.6677 - val_accuracy: 0.5808 - val_loss: 1.6928
# Epoch 2/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 72s 459ms/step - accuracy: 0.7381 - loss: 1.1736 - val_accuracy: 0.9050 - val_loss: 0.4369
# Epoch 3/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 73s 460ms/step - accuracy: 0.9280 - loss: 0.3544 - val_accuracy: 0.9500 - val_loss: 0.2730
# Epoch 4/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 73s 460ms/step - accuracy: 0.9722 - loss: 0.1670 - val_accuracy: 0.9500 - val_loss: 0.2423
# Epoch 5/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 72s 458ms/step - accuracy: 0.9854 - loss: 0.0941 - val_accuracy: 0.9542 - val_loss: 0.2008
# Epoch 6/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 72s 457ms/step - accuracy: 0.9873 - loss: 0.0722 - val_accuracy: 0.9525 - val_loss: 0.1958
# Epoch 7/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 72s 453ms/step - accuracy: 0.9931 - loss: 0.0555 - val_accuracy: 0.9658 - val_loss: 0.1781
# Epoch 8/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 71s 448ms/step - accuracy: 0.9990 - loss: 0.0206 - val_accuracy: 0.9550 - val_loss: 0.2124
# Epoch 9/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 70s 447ms/step - accuracy: 0.9930 - loss: 0.0394 - val_accuracy: 0.9567 - val_loss: 0.1840
# Epoch 10/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 70s 451ms/step - accuracy: 0.9967 - loss: 0.0219 - val_accuracy: 0.8308 - val_loss: 0.6314
# Epoch 11/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 70s 446ms/step - accuracy: 0.9893 - loss: 0.0600 - val_accuracy: 0.9633 - val_loss: 0.1844
# Epoch 12/50
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 70s 448ms/step - accuracy: 0.9990 - loss: 0.0126 - val_accuracy: 0.8100 - val_loss: 0.6714
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 281ms/step - accuracy: 0.9696 - loss: 0.1527
# Test Loss: 0.17806412279605865
# Test Accuracy: 0.965833306312561

# %%
models_path = '/content/drive/My Drive/CNN_Models/InceptionV3BasedModel4.keras'
# Load the saved model
loaded_model = keras.models.load_model(models_path)

# Evaluate the model on the test dataset
test_loss, test_accuracy = loaded_model.evaluate(test_data)
print('Loaded Model Test Loss:', test_loss)
print('Loaded Model Test Accuracy:', test_accuracy)

# %%
# Measure inference time on L4 GPU
num_samples = len(val_data.filenames)
total_time = 0
num_batches = len(val_data)

# Load the trained model
model_path = '/content/drive/My Drive/CNN_Models/InceptionV3BasedModel4.keras'
model = tf.keras.models.load_model(model_path)


for i in range(num_batches):
    images, _ = val_data[i]  # Get batch of images
    start_time = time.time()
    _ = model.predict(images, verbose=0)  # Run inference
    end_time = time.time()
    total_time += (end_time - start_time)

# Compute average inference time per image
avg_inference_time = total_time / num_samples
print(f'Average inference time per image: {avg_inference_time:.6f} seconds')
# Out:
# Average inference time per image: 0.030222 seconds

# %% [markdown]
# #Model5 (1 SEBlock with 20% of Dataset for Training)

# %%
# Define the base model
trainable_base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

for layer in trainable_base_model.layers[-31:]:
  layer.trainable = True

for layer in trainable_base_model.layers[:-31]:
  layer.trainable = False

trainable_base_model.summary()

# %%
def squeeze_excite_block(input_tensor, ratio):
    """
    Create a Squeeze-and-Excitation block.

    Args:
        input_tensor: Input Keras tensor (e.g., output of a convolutional layer).
        ratio: Reduction ratio for the bottleneck (usually 16).

    Returns:
        Keras tensor after applying the SE block.
    """
    # Get the number of channels in the input tensor
    channel_axis = -1
    channels = input_tensor.shape[channel_axis]

    # Squeeze: Global Average Pooling
    se = GlobalAveragePooling2D()(input_tensor)

    # Excitation: Bottleneck structure
    se = Dense(channels // ratio, activation='relu')(se)  # Bottleneck (reduce channels)
    se = Dense(channels, activation='sigmoid')(se)       # Restore channels

    # Reshape to match the input tensor dimensions
    se = Reshape((1, 1, channels))(se)

    # Recalibrate: Scale the input tensor with the channel-wise weights
    x = Multiply()([input_tensor, se])

    return x

# %%
#Code for the whole process
x = trainable_base_model.output
x = squeeze_excite_block(x, 16)
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.10)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.10)(x)
output_tensor = Dense(60, activation='softmax')(x)

# %%
#Final Model
model5 = Model(inputs=trainable_base_model.input, outputs=output_tensor)
model5.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
model5.summary()

# %%
checkpoint_filepath = '/content/drive/My Drive/CNN_Models/20%InceptionV3BasedModel4.keras'

# %%
# Define callbacks
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

model_checkpoint = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    save_best_only=True
)

# %%
Train_dataset_path = '/content/drive/MyDrive/Reverse/Train20Percent'
Validation_dataset_path = '/content/drive/MyDrive/Reverse/Validation'
Test_dataset_path = '/content/drive/MyDrive/Reverse/Test'

# %%
image_size = (299, 299)

# Create a data generator
datagen = ImageDataGenerator(rescale=1./255)

# Load training data
reduced_train_data = datagen.flow_from_directory(
    Train_dataset_path,
    target_size=image_size,
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)

# Load validation data
val_data = datagen.flow_from_directory(
    Validation_dataset_path,
    target_size=image_size,
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Load test data
test_data = datagen.flow_from_directory(
    Test_dataset_path,
    target_size=image_size,
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# %%
history = model5.fit(
    x = reduced_train_data,
    epochs=50,
    validation_data=val_data,
    callbacks=[early_stopping, model_checkpoint]
)

test_loss, test_accuracy = model5.evaluate(val_data)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)


# Plot training and test accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training and test loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1707s 45s/step - accuracy: 0.0423 - loss: 4.0421 - val_accuracy: 0.1217 - val_loss: 3.9044
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 739ms/step - accuracy: 0.3070 - loss: 3.4976 - val_accuracy: 0.2983 - val_loss: 3.3682
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 29s 754ms/step - accuracy: 0.4807 - loss: 2.6764 - val_accuracy: 0.5683 - val_loss: 2.3006
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 29s 767ms/step - accuracy: 0.7684 - loss: 1.4690 - val_accuracy: 0.7333 - val_loss: 1.3104
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 748ms/step - accuracy: 0.9002 - loss: 0.6426 - val_accuracy: 0.8242 - val_loss: 0.8776
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 739ms/step - accuracy: 0.9763 - loss: 0.2999 - val_accuracy: 0.8392 - val_loss: 0.7356
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 743ms/step - accuracy: 0.9860 - loss: 0.1577 - val_accuracy: 0.8642 - val_loss: 0.6300
# Epoch 8/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 753ms/step - accuracy: 0.9991 - loss: 0.0998 - val_accuracy: 0.8708 - val_loss: 0.5743
# Epoch 9/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 752ms/step - accuracy: 1.0000 - loss: 0.0700 - val_accuracy: 0.8758 - val_loss: 0.5383
# Epoch 10/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 29s 750ms/step - accuracy: 0.9989 - loss: 0.0560 - val_accuracy: 0.8817 - val_loss: 0.5088
# Epoch 11/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 29s 764ms/step - accuracy: 1.0000 - loss: 0.0365 - val_accuracy: 0.8792 - val_loss: 0.4874
# Epoch 12/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 29s 762ms/step - accuracy: 1.0000 - loss: 0.0328 - val_accuracy: 0.8850 - val_loss: 0.4794
# Epoch 13/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 29s 751ms/step - accuracy: 1.0000 - loss: 0.0281 - val_accuracy: 0.8892 - val_loss: 0.4664
# Epoch 14/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 29s 743ms/step - accuracy: 1.0000 - loss: 0.0201 - val_accuracy: 0.8983 - val_loss: 0.4610
# Epoch 15/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 29s 746ms/step - accuracy: 0.9980 - loss: 0.0211 - val_accuracy: 0.8925 - val_loss: 0.4559
# Epoch 16/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 741ms/step - accuracy: 1.0000 - loss: 0.0172 - val_accuracy: 0.8975 - val_loss: 0.4425
# Epoch 17/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 29s 745ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.9000 - val_loss: 0.4368
# Epoch 18/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 706ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 0.8925 - val_loss: 0.4475
# Epoch 19/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 26s 702ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.8967 - val_loss: 0.4375
# Epoch 20/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 741ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.8942 - val_loss: 0.4338
# Epoch 21/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 29s 752ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.8975 - val_loss: 0.4226
# Epoch 22/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 718ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.9008 - val_loss: 0.4253
# Epoch 23/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 742ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.9075 - val_loss: 0.4087
# Epoch 24/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 714ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.8975 - val_loss: 0.4251
# Epoch 25/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 26s 698ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.8992 - val_loss: 0.4196
# Epoch 26/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 26s 701ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9000 - val_loss: 0.4102
# Epoch 27/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 715ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.9017 - val_loss: 0.4132
# Epoch 28/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 27s 704ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.9025 - val_loss: 0.4106
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 294ms/step - accuracy: 0.9012 - loss: 0.4402
# Test Loss: 0.4087154269218445
# Test Accuracy: 0.9075000286102295

# %%
models_path = '/content/drive/My Drive/CNN_Models/20%InceptionV3BasedModel4.keras'
# Load the saved model
loaded_model = keras.models.load_model(models_path)

# Evaluate the model on the test dataset
test_loss, test_accuracy = loaded_model.evaluate(test_data)
print('Loaded Model Test Loss:', test_loss)
print('Loaded Model Test Accuracy:', test_accuracy)

# %% [markdown]
# #Model6 (1 SEBlock with 10% of Dataset for Training)

# %%
# Define the base model
trainable_base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

for layer in trainable_base_model.layers[-31:]:
  layer.trainable = True

for layer in trainable_base_model.layers[:-31]:
  layer.trainable = False

trainable_base_model.summary()

# %%
def squeeze_excite_block(input_tensor, ratio):
    """
    Create a Squeeze-and-Excitation block.

    Args:
        input_tensor: Input Keras tensor (e.g., output of a convolutional layer).
        ratio: Reduction ratio for the bottleneck (usually 16).

    Returns:
        Keras tensor after applying the SE block.
    """
    # Get the number of channels in the input tensor
    channel_axis = -1
    channels = input_tensor.shape[channel_axis]

    # Squeeze: Global Average Pooling
    se = GlobalAveragePooling2D()(input_tensor)

    # Excitation: Bottleneck structure
    se = Dense(channels // ratio, activation='relu')(se)  # Bottleneck (reduce channels)
    se = Dense(channels, activation='sigmoid')(se)       # Restore channels

    # Reshape to match the input tensor dimensions
    se = Reshape((1, 1, channels))(se)

    # Recalibrate: Scale the input tensor with the channel-wise weights
    x = Multiply()([input_tensor, se])

    return x

# %%
#Code for the whole process
x = trainable_base_model.output
x = squeeze_excite_block(x, 16)
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.10)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.10)(x)
output_tensor = Dense(60, activation='softmax')(x)

# %%
#Final Model
model6 = Model(inputs=trainable_base_model.input, outputs=output_tensor)
model6.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
model6.summary()

# %%
checkpoint_filepath = '/content/drive/My Drive/CNN_Models/10%InceptionV3BasedModel4.keras'

# %%
# Define callbacks
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

model_checkpoint = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    save_best_only=True
)

# %%
Train_dataset_path = '/content/drive/MyDrive/Reverse/Train10Percent'
Validation_dataset_path = '/content/drive/MyDrive/Reverse/Validation'
Test_dataset_path = '/content/drive/MyDrive/Reverse/Test'

# %%
image_size = (299, 299)

# Create a data generator
datagen = ImageDataGenerator(rescale=1./255)

# Load training data
reduced_train_data = datagen.flow_from_directory(
    Train_dataset_path,
    target_size=image_size,
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)

# Load validation data
val_data = datagen.flow_from_directory(
    Validation_dataset_path,
    target_size=image_size,
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Load test data
test_data = datagen.flow_from_directory(
    Test_dataset_path,
    target_size=image_size,
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# %%
history = model6.fit(
    x = reduced_train_data,
    epochs=50,
    validation_data=val_data,
    callbacks=[early_stopping, model_checkpoint]
)

test_loss, test_accuracy = model6.evaluate(val_data)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)


# Plot training and test accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training and test loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1454s 78s/step - accuracy: 0.0393 - loss: 4.0754 - val_accuracy: 0.0867 - val_loss: 4.0243
# Epoch 2/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.2407 - loss: 3.7891 - val_accuracy: 0.1600 - val_loss: 3.8916
# Epoch 3/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.3603 - loss: 3.4416 - val_accuracy: 0.2175 - val_loss: 3.6905
# Epoch 4/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.5068 - loss: 2.9262 - val_accuracy: 0.3458 - val_loss: 3.3506
# Epoch 5/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.6465 - loss: 2.3452 - val_accuracy: 0.4175 - val_loss: 2.8901
# Epoch 6/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7931 - loss: 1.5802 - val_accuracy: 0.5358 - val_loss: 2.3153
# Epoch 7/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8969 - loss: 0.9860 - val_accuracy: 0.6650 - val_loss: 1.8199
# Epoch 8/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9711 - loss: 0.5030 - val_accuracy: 0.6817 - val_loss: 1.5187
# Epoch 9/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9843 - loss: 0.2803 - val_accuracy: 0.7200 - val_loss: 1.3186
# Epoch 10/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9971 - loss: 0.1498 - val_accuracy: 0.7383 - val_loss: 1.2052
# Epoch 11/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9997 - loss: 0.0997 - val_accuracy: 0.7550 - val_loss: 1.1066
# Epoch 12/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0662 - val_accuracy: 0.7617 - val_loss: 1.0513
# Epoch 13/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0547 - val_accuracy: 0.7683 - val_loss: 1.0161
# Epoch 14/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9996 - loss: 0.0464 - val_accuracy: 0.7725 - val_loss: 0.9971
# Epoch 15/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0386 - val_accuracy: 0.7842 - val_loss: 0.9608
# Epoch 16/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0347 - val_accuracy: 0.7883 - val_loss: 0.9413
# Epoch 17/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0253 - val_accuracy: 0.7883 - val_loss: 0.9154
# Epoch 18/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0287 - val_accuracy: 0.7958 - val_loss: 0.9020
# Epoch 19/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0225 - val_accuracy: 0.7925 - val_loss: 0.8908
# Epoch 20/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0198 - val_accuracy: 0.7825 - val_loss: 0.8944
# Epoch 21/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0199 - val_accuracy: 0.7867 - val_loss: 0.8888
# Epoch 22/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0171 - val_accuracy: 0.7900 - val_loss: 0.8750
# Epoch 23/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 0.7950 - val_loss: 0.8585
# Epoch 24/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.7992 - val_loss: 0.8561
# Epoch 25/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.7942 - val_loss: 0.8481
# Epoch 26/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.7900 - val_loss: 0.8392
# Epoch 27/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.7933 - val_loss: 0.8338
# Epoch 28/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.7950 - val_loss: 0.8295
# Epoch 29/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 0.7950 - val_loss: 0.8252
# Epoch 30/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.7983 - val_loss: 0.8209
# Epoch 31/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.7950 - val_loss: 0.8202
# Epoch 32/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9944 - loss: 0.0161 - val_accuracy: 0.7875 - val_loss: 0.8381
# Epoch 33/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.7950 - val_loss: 0.8266
# Epoch 34/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.7992 - val_loss: 0.8111
# Epoch 35/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.7967 - val_loss: 0.8019
# Epoch 36/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.7958 - val_loss: 0.7989
# Epoch 37/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.7983 - val_loss: 0.7947
# Epoch 38/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.7967 - val_loss: 0.7909
# Epoch 39/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.7967 - val_loss: 0.7904
# Epoch 40/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.7967 - val_loss: 0.7845
# Epoch 41/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.7992 - val_loss: 0.7754
# Epoch 42/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.8017 - val_loss: 0.7697
# Epoch 43/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.8025 - val_loss: 0.7696
# Epoch 44/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8025 - val_loss: 0.7713
# Epoch 45/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.8050 - val_loss: 0.7704
# Epoch 46/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8050 - val_loss: 0.7662
# Epoch 47/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.8008 - val_loss: 0.7662
# Epoch 48/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.8025 - val_loss: 0.7607
# Epoch 49/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8042 - val_loss: 0.7582
# Epoch 50/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8017 - val_loss: 0.7607
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 12s 301ms/step - accuracy: 0.7987 - loss: 0.7577
# Test Loss: 0.7581955194473267
# Test Accuracy: 0.8041666746139526

# %%
models_path = '/content/drive/My Drive/CNN_Models/10%InceptionV3BasedModel4.keras'
# Load the saved model
loaded_model = keras.models.load_model(models_path)

# Evaluate the model on the test dataset
test_loss, test_accuracy = loaded_model.evaluate(test_data)
print('Loaded Model Test Loss:', test_loss)
print('Loaded Model Test Accuracy:', test_accuracy)

# %% [markdown]
# #Model7 (1 SEBlock with 5% of Dataset for Training)

# %%
# Define the base model
trainable_base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

for layer in trainable_base_model.layers[-31:]:
  layer.trainable = True

for layer in trainable_base_model.layers[:-31]:
  layer.trainable = False

trainable_base_model.summary()

# %%
def squeeze_excite_block(input_tensor, ratio):
    """
    Create a Squeeze-and-Excitation block.

    Args:
        input_tensor: Input Keras tensor (e.g., output of a convolutional layer).
        ratio: Reduction ratio for the bottleneck (usually 16).

    Returns:
        Keras tensor after applying the SE block.
    """
    # Get the number of channels in the input tensor
    channel_axis = -1
    channels = input_tensor.shape[channel_axis]

    # Squeeze: Global Average Pooling
    se = GlobalAveragePooling2D()(input_tensor)

    # Excitation: Bottleneck structure
    se = Dense(channels // ratio, activation='relu')(se)  # Bottleneck (reduce channels)
    se = Dense(channels, activation='sigmoid')(se)       # Restore channels

    # Reshape to match the input tensor dimensions
    se = Reshape((1, 1, channels))(se)

    # Recalibrate: Scale the input tensor with the channel-wise weights
    x = Multiply()([input_tensor, se])

    return x

# %%
#Code for the whole process
x = trainable_base_model.output
x = squeeze_excite_block(x, 16)
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.10)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.10)(x)
output_tensor = Dense(60, activation='softmax')(x)

# %%
#Final Model
model7 = Model(inputs=trainable_base_model.input, outputs=output_tensor)
model7.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
model7.summary()

# %%
checkpoint_filepath = '/content/drive/My Drive/CNN_Models/5%InceptionV3BasedModel4.keras'

# %%
# Define callbacks
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

model_checkpoint = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    save_best_only=True
)

# %%
Train_dataset_path = '/content/drive/MyDrive/Reverse/Train5Percent'
Validation_dataset_path = '/content/drive/MyDrive/Reverse/Validation'
Test_dataset_path = '/content/drive/MyDrive/Reverse/Test'

# %%
image_size = (299, 299)

# Create a data generator
datagen = ImageDataGenerator(rescale=1./255)

# Load training data
reduced_train_data = datagen.flow_from_directory(
    Train_dataset_path,
    target_size=image_size,
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)

# Load validation data
val_data = datagen.flow_from_directory(
    Validation_dataset_path,
    target_size=image_size,
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Load test data
test_data = datagen.flow_from_directory(
    Test_dataset_path,
    target_size=image_size,
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# %%
history = model7.fit(
    x = reduced_train_data,
    epochs=50,
    validation_data=val_data,
    callbacks=[early_stopping, model_checkpoint]
)

test_loss, test_accuracy = model7.evaluate(val_data)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)


# Plot training and test accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training and test loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 398s 40s/step - accuracy: 0.0343 - loss: 4.0799 - val_accuracy: 0.0508 - val_loss: 4.0643
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.1818 - loss: 3.8701 - val_accuracy: 0.0708 - val_loss: 4.0134
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.2560 - loss: 3.6623 - val_accuracy: 0.1033 - val_loss: 3.9473
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.3428 - loss: 3.4495 - val_accuracy: 0.1217 - val_loss: 3.8569
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.4459 - loss: 3.1266 - val_accuracy: 0.1458 - val_loss: 3.7554
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.5925 - loss: 2.7590 - val_accuracy: 0.1583 - val_loss: 3.6265
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.6680 - loss: 2.4889 - val_accuracy: 0.2108 - val_loss: 3.4539
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.7296 - loss: 2.1252 - val_accuracy: 0.2775 - val_loss: 3.2444
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.8359 - loss: 1.6455 - val_accuracy: 0.3117 - val_loss: 3.0018
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9384 - loss: 1.1564 - val_accuracy: 0.3992 - val_loss: 2.7719
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9466 - loss: 0.8566 - val_accuracy: 0.4183 - val_loss: 2.5685
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9800 - loss: 0.5535 - val_accuracy: 0.4458 - val_loss: 2.3766
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.3412 - val_accuracy: 0.4942 - val_loss: 2.2122
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.2475 - val_accuracy: 0.5342 - val_loss: 2.0864
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9964 - loss: 0.1442 - val_accuracy: 0.5642 - val_loss: 1.9857
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.1271 - val_accuracy: 0.5825 - val_loss: 1.9047
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.1026 - val_accuracy: 0.5867 - val_loss: 1.8469
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.0718 - val_accuracy: 0.6000 - val_loss: 1.7859
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.0659 - val_accuracy: 0.6075 - val_loss: 1.7325
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.0430 - val_accuracy: 0.6158 - val_loss: 1.6990
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.0398 - val_accuracy: 0.6142 - val_loss: 1.6721
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.0452 - val_accuracy: 0.6192 - val_loss: 1.6476
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.0320 - val_accuracy: 0.6300 - val_loss: 1.6233
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 1.0000 - loss: 0.0361 - val_accuracy: 0.6342 - val_loss: 1.6062
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0346 - val_accuracy: 0.6233 - val_loss: 1.6180
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0333 - val_accuracy: 0.6275 - val_loss: 1.6079
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 1.0000 - loss: 0.0250 - val_accuracy: 0.6283 - val_loss: 1.5818
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.0199 - val_accuracy: 0.6333 - val_loss: 1.5603
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.0214 - val_accuracy: 0.6342 - val_loss: 1.5509
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.0249 - val_accuracy: 0.6325 - val_loss: 1.5428
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 0.6358 - val_loss: 1.5280
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.0246 - val_accuracy: 0.6367 - val_loss: 1.5133
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.6433 - val_loss: 1.5017
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.0122 - val_accuracy: 0.6433 - val_loss: 1.4994
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 0.6425 - val_loss: 1.4885
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.0122 - val_accuracy: 0.6500 - val_loss: 1.4718
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.6633 - val_loss: 1.4521
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 0.6617 - val_loss: 1.4471
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 1.0000 - loss: 0.0174 - val_accuracy: 0.6542 - val_loss: 1.4505
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 0.6508 - val_loss: 1.4582
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.9970 - loss: 0.0138 - val_accuracy: 0.6333 - val_loss: 1.4884
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0119 - val_accuracy: 0.6358 - val_loss: 1.5010
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 0.6425 - val_loss: 1.4755
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 12s 314ms/step - accuracy: 0.6633 - loss: 1.4019
# Test Loss: 1.4471330642700195
# Test Accuracy: 0.6616666913032532

# %%
models_path = '/content/drive/My Drive/CNN_Models/5%InceptionV3BasedModel4.keras'
# Load the saved model
loaded_model = keras.models.load_model(models_path)

# Evaluate the model on the test dataset
test_loss, test_accuracy = loaded_model.evaluate(test_data)
print('Loaded Model Test Loss:', test_loss)
print('Loaded Model Test Accuracy:', test_accuracy)
